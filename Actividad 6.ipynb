# %% [markdown]
# # Actividad - Estadística básica

# %% [markdown]
# * **Nombre:** Diego Vega Camacho
# * **Matrícula:** A01704492

# %% [markdown]
# **Entregar:** Archivo PDF de la actividad, así como el archivo .ipynb en tu repositorio.
# **Nota:** Recuerda habrá una penalización de **50** puntos si la actividad fue entregada fuera de la fecha límite.

# %% [markdown]
# Carga el conjunto de datos `insurance.csv` (se encuentra en el repositorio de la clase) y realiza un análisis estadístico de las variables.

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-d932833d-eded-4225-b6fa-1e0ed616a962" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d932833d-eded-4225-b6fa-1e0ed616a962">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving insurance.csv to insurance.csv
# User uploaded file "insurance.csv" with length 54289 bytes

# %%
df = pd.read_csv('insurance.csv')
df.head(6)
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520
# 5   31  female  25.740         0     no  southeast   3756.62160

# %% [markdown]
# El conjunto de datos contiene información demográfica sobre los asegurados en una compañía de seguros:
# * **age**: Edad del asegurado principal
# * **sex**: Género del asegurado. female o male
# * **bmi**: Índice de masa corporal
# * **children**: Número de hijos que estan cubiertos con la poliza.
# * **smoke**: ¿El beneficiario fuma? (*yes*/*no*)
# * **region**: ¿Dónde vive el beneficiario? Estos datos son de Estados Unidos. Regiones disponibles: northeast, southeast, southwest, northwest
# * **charges**: Costo del seguro.

# %%
df.describe()
# Tabla resumen con los estadísticas generales de las variables
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df.corr()
# Correlación de variables entre si
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %%
selected = df[['bmi','charges']]
print('Correlación: ', selected['bmi'].corr(selected['charges']))
# Determina si existe o no una correlación entre el índice de masa corporal 
# (bmi) y el costo del seguro.
# Out:
# Correlación:  0.19834096883362895

# %%
df['sex'].value_counts()
# ¿Cuántas personas aseguradas son hombre y cuántas son mujeres?
# Out:
# male      676
# female    662
# Name: sex, dtype: int64

# %%
pd.crosstab(df['region'], df['sex'])
# ¿Cuántos hombres y mujeres asegurados viven en cada región?
# Out:
# sex        female  male
# region
# northeast     161   163
# northwest     164   161
# southeast     175   189
# southwest     162   163

# %%
df.groupby(['smoker']).mean()[['charges']]
# En promedio, ¿quién paga más de cuota de seguro? ¿Los fumadores o los no 
# fumadores? Muéstralo con los datos.
# Out:
#              charges
# smoker
# no       8434.268298
# yes     32050.231832

# %%
df.groupby(['children', 'sex']).agg(['min', 'max'])[['charges']]
# ¿Cuáles son las cuotas mínimas y máximas que las personan pagan dependiendo
# del género y del número de hijos?
# Out:
#                     charges
#                         min          max
# children sex
# 0        female  1607.51010  63770.42801
#          male    1121.87390  62592.87309
# 1        female  2201.09710  58571.07448
#          male    1711.02680  51194.55914
# 2        female  2801.25880  47305.30500
#          male    2304.00220  49577.66240
# 3        female  4234.92700  46661.44240
#          male    3443.06400  60021.39897
# 4        female  4561.18850  36580.28216
#          male    4504.66240  40182.24600
# 5        female  4687.79700  19023.26000
#          male    4915.05985  14478.33015

# %%
df.groupby(['region', 'sex','smoker']).mean()[['bmi']]
# Índice de masa corporal promedio para hombre y mujeres dependiendo
# región en la que viven y si son fumadores. ¿Impacta eso en la tarifa del 
# seguro?
# Out:
#                                bmi
# region    sex    smoker
# northeast female no      29.777462
#                  yes     27.261724
#           male   no      28.861760
#                  yes     29.560000
# northwest female no      29.488704
#                  yes     28.296897
#           male   no      28.930379
#                  yes     29.983966
# southeast female no      32.780000
#                  yes     32.251389
#           male   no      34.129552
#                  yes     33.650000
# southwest female no      30.050355
#                  yes     30.128571
#           male   no      31.019841
#                  yes     31.502703
